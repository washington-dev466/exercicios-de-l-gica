# %% [markdown]
# <a href="https://colab.research.google.com/github/washington-dev466/exercicios-de-l-gica/blob/main/Exerc%C3%ADcios_de_Lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CRIANDO LISTAS

# %%
frutas = ["maça", "laranja", "uva"]
print(frutas[0])
# Out:
# maça
